# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("metadata.csv")
df
# Out:
#              filename                                           dc.title  \
# 0      objects/Kodoku                                             Kodoku
# 1     objects/147.tif                                     Low, George M.
# 2  objects/1869-11-20               The Rensselaer Polytechnic v.1, no.5
# 3       objects/grebe  Vision based control of a mobile robot for dri...
#
#                                       dc.creator  \
# 0                               Jalbert, Patrick
# 1  National Aeronautics and Space Administration
# 2                                            NaN
# 3                              Grebe, Gregory S.
#
#                                       dc.description       dc.description.1  \
# 0  EMAC Thesis project. Completed as part of the ...                    NaN
# 1  George M. Low, Manager Apollo Spacecraft progr...                    NaN
# 2                                                NaN                    NaN
# 3                                           May 2017  School of Engineering
#
#                                     dcterms.abstract  \
# 0  Kodoku is a simple story about the difficulty ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#                                         dc.publisher  \
# 0  The School of Humanities, Arts and Social Scie...
# 1      National Aeronautics and Space Administration
# 2             Troy, N.Y.: The Rensselaer Polytechnic
# 3         Rensselaer Polytechnic Institute, Troy, NY
#
#                                   dc.contributor    dc.contributor.1  \
# 0                 Lawson, Shawn. Faculty advisor                 NaN
# 1  National Aeronautics and Space Administration                 NaN
# 2                                            NaN                 NaN
# 3                                   Wen, John T.  Julius, Anak Agung
#
#   dc.contributor.2     ...      dcterms.created         physical location  \
# 0              NaN     ...                  NaN                       NaN
# 1              NaN     ...               1969.0  87-12, Box 135, Folder 4
# 2              NaN     ...                  NaN                       NaN
# 3  Fajen, Brett R.     ...                  NaN                       NaN
#
#                   dcterms.source                 image specifications  \
# 0                            NaN                                  NaN
# 1                          87-12  600 dpi, grayscale, Epson GT 10000+
# 2  Polytechnic microfilm reel #1                                  NaN
# 3                            NaN                                  NaN
#
#   dcterms.thesis.degree.name  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                         MS
#
#                     dcterms.thesis.degree.discipline  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Dept. of Electrical, Computer, and Systems Eng...
#
#                                   dcterms.abstract.1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Autonomous navigation of a shared roadway is a...
#
#                                   dcterms.abstract.2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The second controller is based on using the vi...
#
#                               dcterms.accessRights.1 dc.language
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3  Users may download and share copies with attri...         ENG
#
# [4 rows x 41 columns]

# %%
listoffields = ['dc.creator', 'dc.contributor', 'dc.contributor.1']


for field in listoffields:
    pattern = re.search('(?<=\.)[a-z]*', field)
    print pattern.group(0)
    #df = df[field].apply(lambda x: "{}{}".format('~' + pattern.group(0), x))

#x = pd.Series(df['dc.creator'])   
#pd.Series(df['dc.creator']).str.cat(['creator'], sep='~')

#x
df['dc.creator'] = df['dc.creator'].apply(lambda x: x.str.cat(['creator'], sep= ' | '))
df
# Out:
# creator
# contributor
# contributor
# AttributeErrorTraceback (most recent call last)
# <ipython-input-392-4cc245f78a09> in <module>()
#      11
#      12 #x
# ---> 13 df['dc.creator'] = df['dc.creator'].apply(lambda x: x.str.cat(['creator'], sep= ' | '))
#      14 df
#
# C:\Users\Andrea\Anaconda2\lib\site-packages\pandas\core\series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-392-4cc245f78a09> in <lambda>(x)
#      11
#      12 #x
# ---> 13 df['dc.creator'] = df['dc.creator'].apply(lambda x: x.str.cat(['creator'], sep= ' | '))
#      14 df
#
# AttributeError: 'str' object has no attribute 'str'
